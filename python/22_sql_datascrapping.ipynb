# %%
import numpy as np
import pandas as pd
import mysql.connector
data=pd.read_csv('deliveries.csv')
conn=mysql.connector.connect(host='localhost',user='root',password='',database='world')
pd.read_sql_query("SELECT * FROM COUNTRY WHERE REGION LIKE 'CARIBBEAN'",conn)
# Out:
# C:\Users\atsj6\AppData\Local\Temp\ipykernel_8320\658165758.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM COUNTRY WHERE REGION LIKE 'CARIBBEAN'",conn)
#    Code                              Name      Continent     Region  \
# 0   ABW                             Aruba  North America  Caribbean
# 1   AIA                          Anguilla  North America  Caribbean
# 2   ANT              Netherlands Antilles  North America  Caribbean
# 3   ATG               Antigua and Barbuda  North America  Caribbean
# 4   BHS                           Bahamas  North America  Caribbean
# 5   BRB                          Barbados  North America  Caribbean
# 6   CUB                              Cuba  North America  Caribbean
# 7   CYM                    Cayman Islands  North America  Caribbean
# 8   DMA                          Dominica  North America  Caribbean
# 9   DOM                Dominican Republic  North America  Caribbean
# 10  GLP                        Guadeloupe  North America  Caribbean
# 11  GRD                           Grenada  North America  Caribbean
# 12  HTI                             Haiti  North America  Caribbean
# 13  JAM                           Jamaica  North America  Caribbean
# 14  KNA             Saint Kitts and Nevis  North America  Caribbean
# 15  LCA                       Saint Lucia  North America  Caribbean
# 16  MSR                        Montserrat  North America  Caribbean
# 17  MTQ                        Martinique  North America  Caribbean
# 18  PRI                       Puerto Rico  North America  Caribbean
# 19  TCA          Turks and Caicos Islands  North America  Caribbean
# 20  TTO               Trinidad and Tobago  North America  Caribbean
# 21  VCT  Saint Vincent and the Grenadines  North America  Caribbean
# 22  VGB           Virgin Islands, British  North America  Caribbean
# 23  VIR              Virgin Islands, U.S.  North America  Caribbean
#
#     SurfaceArea  IndepYear  Population  LifeExpectancy      GNP   GNPOld  \
# 0         193.0        NaN      103000            78.4    828.0    793.0
# 1          96.0        NaN        8000            76.1     63.2      NaN
# 2         800.0        NaN      217000            74.7   1941.0      NaN
# 3         442.0     1981.0       68000            70.5    612.0    584.0
# 4       13878.0     1973.0      307000            71.1   3527.0   3347.0
# 5         430.0     1966.0      270000            73.0   2223.0   2186.0
# 6      110861.0     1902.0    11201000            76.2  17843.0  18862.0
# 7         264.0        NaN       38000            78.9   1263.0   1186.0
# 8         751.0     1978.0       71000            73.4    256.0    243.0
# 9       48511.0     1844.0     8495000            73.2  15846.0  15076.0
# 10       1705.0        NaN      456000            77.0   3501.0      NaN
# 11        344.0     1974.0       94000            64.5    318.0      NaN
# 12      27750.0     1804.0     8222000            49.2   3459.0   3107.0
# 13      10990.0     1962.0     2583000            75.2   6871.0   6722.0
# 14        261.0     1983.0       38000            70.7    299.0      NaN
# 15        622.0     1979.0      154000            72.3    571.0      NaN
# 16        102.0        NaN       11000            78.0    109.0      NaN
# 17       1102.0        NaN      395000            78.3   2731.0   2559.0
# 18       8875.0        NaN     3869000            75.6  34100.0  32100.0
# 19        430.0        NaN       17000            73.3     96.0      NaN
# 20       5130.0     1962.0     1295000            68.0   6232.0   5867.0
# 21        388.0     1979.0      114000            72.3    285.0      NaN
# 22        151.0        NaN       21000            75.4    612.0    573.0
# 23        347.0        NaN       93000            78.1      0.0      NaN
#
#                               LocalName  \
# 0                                 Aruba
# 1                              Anguilla
# 2                  Nederlandse Antillen
# 3                   Antigua and Barbuda
# 4                           The Bahamas
# 5                              Barbados
# 6                                  Cuba
# 7                        Cayman Islands
# 8                              Dominica
# 9                  República Dominicana
# 10                           Guadeloupe
# 11                              Grenada
# 12                          Haïti/Dayti
# 13                              Jamaica
# 14                Saint Kitts and Nevis
# 15                          Saint Lucia
# 16                           Montserrat
# 17                           Martinique
# 18                          Puerto Rico
# 19         The Turks and Caicos Islands
# 20                  Trinidad and Tobago
# 21     Saint Vincent and the Grenadines
# 22               British Virgin Islands
# 23  Virgin Islands of the United States
#
#                                   GovernmentForm               HeadOfState  \
# 0   Nonmetropolitan Territory of The Netherlands                   Beatrix
# 1                  Dependent Territory of the UK              Elisabeth II
# 2   Nonmetropolitan Territory of The Netherlands                   Beatrix
# 3                        Constitutional Monarchy              Elisabeth II
# 4                        Constitutional Monarchy              Elisabeth II
# 5                        Constitutional Monarchy              Elisabeth II
# 6                           Socialistic Republic          Fidel Castro Ruz
# 7                  Dependent Territory of the UK              Elisabeth II
# 8                                       Republic               Vernon Shaw
# 9                                       Republic  Hipólito Mejía Domínguez
# 10                 Overseas Department of France            Jacques Chirac
# 11                       Constitutional Monarchy              Elisabeth II
# 12                                      Republic    Jean-Bertrand Aristide
# 13                       Constitutional Monarchy              Elisabeth II
# 14                       Constitutional Monarchy              Elisabeth II
# 15                       Constitutional Monarchy              Elisabeth II
# 16                 Dependent Territory of the UK              Elisabeth II
# 17                 Overseas Department of France            Jacques Chirac
# 18                        Commonwealth of the US            George W. Bush
# 19                 Dependent Territory of the UK              Elisabeth II
# 20                                      Republic     Arthur N. R. Robinson
# 21                       Constitutional Monarchy              Elisabeth II
# 22                 Dependent Territory of the UK              Elisabeth II
# 23                                  US Territory            George W. Bush
#
#     Capital Code2
# 0       129    AW
# 1        62    AI
# 2        33    AN
# 3        63    AG
# 4       148    BS
# 5       174    BB
# 6      2413    CU
# 7       553    KY
# 8       586    DM
# 9       587    DO
# 10      919    GP
# 11      916    GD
# 12      929    HT
# 13     1530    JM
# 14     3064    KN
# 15     3065    LC
# 16     2697    MS
# 17     2508    MQ
# 18     2919    PR
# 19     3423    TC
# 20     3336    TT
# 21     3066    VC
# 22      537    VG
# 23     4067    VI
